# %%
import matplotlib.pyplot as plt
from math import *
from numpy import *

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ylim(0, 1150)
ax.set(title="Selection Sort (Tiempo)", xlabel="Número de datos", ylabel="Tiempo (milisegundos)")
ax.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,5.0,34.0,118.0,370.0,556.0] , color='blue', linewidth=3, label="Ordenados")
ax.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,1.3,9.766666666666667,41.46666666666667,98.1,139.26666666666668] , color='red', linewidth=3, label="Aleatorio")
ax.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,2.0,21.0,99.0,334.0,583.0] , color='green', linewidth=3, label="Inverso")
leg = plt.legend(loc='upper left')
fig.savefig('/Users/robertodelriosalgado/Desktop/EDA/SST.png')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
plt.ylim(0, 1150)
ax1.set(title="Insertion Sort (Tiempo)", xlabel="Número de datos", ylabel="Tiempo (milisegundos)")
ax1.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,9.0,14.0,57.0,190.0,304.0] , color='blue', linewidth=3, label="Ordenados")
ax1.plot([100, 1000, 3000, 6000, 10000, 12213], [0.03333333333333333,1.0,8.7,35.233333333333334,94.2,128.56666666666666] , color='red', linewidth=3, label="Aleatorio")
ax1.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,2.0,31.0,143.0,456.0,739.0] , color='green', linewidth=3, label="Inverso")
leg = plt.legend(loc='upper left')
fig.savefig('/Users/robertodelriosalgado/Desktop/EDA/IST.png')

# %%
fig = plt.figure()
ax2 = fig.add_subplot(111)
plt.ylim(0, 1200)
ax2.set(title="Quick Sort (Tiempo)", xlabel="Número de datos", ylabel="Tiempo (milisegundos)")
ax2.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,3.0,12.0,53.0,21.0,33.0] , color='blue', linewidth=3, label="Ordenados")
ax2.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,0.1,0.5,1.8,4.366666666666666,9.333333333333334] , color='red', linewidth=3, label="Aleatorio")
ax2.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,7.0,118.0,325.0,799.0,1139.0] , color='green', linewidth=3, label="Inverso")
leg = plt.legend(loc='upper left')
fig.savefig('/Users/robertodelriosalgado/Desktop/EDA/QST.png')

# %%
fig = plt.figure()
ax3 = fig.add_subplot(111)
plt.ylim(0, 15)
ax3.set(title="Merge Sort (Tiempo)", xlabel="Número de datos", ylabel="Tiempo (milisegundos)")
ax3.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,1.0,1.0,9.0,10.0,9.0] , color='blue', linewidth=3, label="Ordenados")
ax3.plot([100, 1000, 3000, 6000, 10000, 12213], [0.1,0.8666666666666667,0.6,1.1333333333333333,2.2,2.033333333333333] , color='red', linewidth=3, label="Aleatorio")
ax3.plot([100, 1000, 3000, 6000, 10000, 12213], [0.0,1.0,0.0,1.0,2.0,3.0] , color='green', linewidth=3, label="Inverso")
leg = plt.legend(loc='upper left')
fig.savefig('/Users/robertodelriosalgado/Desktop/EDA/MST.png')

# %%
fig = plt.figure()
ax4 = fig.add_subplot(111)
plt.ylim(0, 100000)
ax4.set(title="Selection Sort (Comparaciones)", xlabel="Número de datos", ylabel="Comparaciones")
ax4.plot([100, 1000, 3000, 6000, 10000, 12213], [315.0,5659.0,19898.0,43680.0,77648.0,97699.0] , color='blue', linewidth=3, label="Ordenados")
ax4.plot([100, 1000, 3000, 6000, 10000, 12213], [312.1,4810.733333333334,14557.6,28012.233333333334,44843.066666666666,52508.8] , color='red', linewidth=3, label="Aleatorio")
ax4.plot([100, 1000, 3000, 6000, 10000, 12213], [316.0,5528.0,19618.0,43581.0,76422.0,97618.0] , color='green', linewidth=3, label="Inverso")
leg = plt.legend(loc='upper left')
fig.savefig('/Users/robertodelriosalgado/Desktop/EDA/SSC.png')

# %%
fig = plt.figure()
ax5 = fig.add_subplot(111)
plt.ylim(0, 4e7)
ax5.set(title="Insertion Sort (Comparaciones)", xlabel="Número de datos", ylabel="Comparaciones")
ax5.plot([100, 1000, 3000, 6000, 10000, 12213], [2255.0,253522.0,2225882.0,8913289.0,2.4772017e7,3.6823757e7] , color='blue', linewidth=3, label="Ordenados")
ax5.plot([100, 1000, 3000, 6000, 10000, 12213], [2497.5666666666666,249364.26666666666,2236941.033333333,8932288.433333334,2.4736065033333335e7,3.6781010333333336e7] , color='red', linewidth=3, label="Aleatorio")
ax5.plot([100, 1000, 3000, 6000, 10000, 12213], [2428.0,246726.0,2277999.0,9110606.0,2.5203238e7,3.7748821e7] , color='green', linewidth=3, label="Inverso")
leg = plt.legend(loc='upper left')
fig.savefig('/Users/robertodelriosalgado/Desktop/EDA/ISC.png')

# %%
fig = plt.figure()
ax6 = fig.add_subplot(111)
plt.ylim(0, 31000)
ax6.set(title="Quick Sort (Comparaciones)", xlabel="Número de datos", ylabel="Comparaciones")
ax6.plot([100, 1000, 3000, 6000, 10000, 12213], [138.0,1836.0,8469.0,13737.0,27666.0,29776.0] , color='blue', linewidth=3, label="Ordenados")
ax6.plot([100, 1000, 3000, 6000, 10000, 12213], [100.66666666666667,1327.4666666666667,3900.4,6627.1,10550.366666666667,12790.266666666666] , color='red', linewidth=3, label="Aleatorio")
ax6.plot([100, 1000, 3000, 6000, 10000, 12213], [66.0,1576.0,5917.0,11260.0,18458.0,29676.0] , color='green', linewidth=3, label="Inverso")
leg = plt.legend(loc='upper left')
fig.savefig('/Users/robertodelriosalgado/Desktop/EDA/QSC.png')

# %%
fig = plt.figure()
ax7 = fig.add_subplot(111)
plt.ylim(0, 78000)
ax7.set(title="Merge Sort (Comparaciones)", xlabel="Número de datos", ylabel="Comparaciones")
ax7.plot([100, 1000, 3000, 6000, 10000, 12213], [266.0,4310.0,15211.0,33352.0,59194.0,74401.0] , color='blue', linewidth=3, label="Ordenados")
ax7.plot([100, 1000, 3000, 6000, 10000, 12213], [262.8666666666667,4334.3,15219.533333333333,33521.03333333333,59421.833333333336,74818.76666666666] , color='red', linewidth=3, label="Aleatorio")
ax7.plot([100, 1000, 3000, 6000, 10000, 12213], [265.0,4342.0,15223.0,33395.0,59320.0,74512.0] , color='green', linewidth=3, label="Inverso")
leg = plt.legend(loc='upper left')
fig.savefig('/Users/robertodelriosalgado/Desktop/EDA/MSC.png')

# %%
import networkx as nx
import numpy as np
import heapdict as hd

# %%
class Grafo:
  def __init__(self):
    self.G={}
    self.visitados={}

  def insertaNodo(self,v1):
    if v1 not in self.G:
      self.G[v1]={}

  def insertaDirigido(self,v1,v2,peso=None):

    if v1 not in self.G:
      self.G[v1]={v2:peso}
    else:   
        self.G[v1][v2]=peso
    if v2 not in self.G:
      self.G[v2]={}

  def inserta(self,v1,v2,peso=None):
    self.insertaDirigido(v1,v2,peso)
    self.insertaDirigido(v2,v1,peso)


  def _recorreDFS(self,actual,lista):

    self.visitados[actual]=True
    lista.append(actual)
    for v in self.G[actual]:
      if not self.visitados[v]:
        self._recorreDFS(v,lista)

  def DFS(self): #Depth First Search, recorrido a profundida
    # inicializar el visitados
    for v in self.G:
      self.visitados[v]=False
    lista=[]
    for v in self.G:
      if not self.visitados[v]:
        self._recorreDFS(v,lista)
    return lista


  def BFS(self):
    for v in self.G:
      self.visitados[v]=False
    lista=[]
    for v in self.G:
      if not self.visitados[v]:
        self._recorreBFS(v,lista)
    return lista

  def _recorreBFS(self,actual,lista):
    cola=[]
    self.visitados[actual]=True
    cola.append(actual)
    while len(cola)!=0:
      actual=cola.pop(0)
      lista.append(actual)
      for vecino in self.G[actual].keys():
        if not self.visitados[vecino]:
          self.visitados[vecino]=True
          cola.append(vecino)


  def Prim(self,v_ini):
    key=hd.heapdict()
    papa={}
    for v in self.G:
      key[v]=np.inf
      papa[v]=None
    key[v_ini]=0
    while len(key)>0:
      actual,costo=key.popitem()
      for vecino in self.G[actual]:
        if vecino in key and self.G[actual][vecino] < key[vecino]:
          key[vecino]=self.G[actual][vecino]
          papa[vecino]=actual

    return papa


  def Dijkstra(self,v_ini):
    key=hd.heapdict()
    papa={}
    for v in self.G:
      key[v]=np.inf
      papa[v]=None
    key[v_ini]=0
    while len(key)>0:
      actual,costo=key.popitem()
      for vecino in self.G[actual]:
        if vecino in key and costo+self.G[actual][vecino] < key[vecino]:
          key[vecino]=costo+self.G[actual][vecino]
          papa[vecino]=actual

    return papa
    
    def caminoHamiltoniano(grafo,actual,lista, visitados):
    
    
    def camino(grafo):
        visitados={}
        lista=[]
        for v in grafo:
            visitados[v]=False

# %%
def caminoHamiltoniano(grafo,actual,lista, visitados):
    
    
def camino(grafo):
    visitados={}
    lista=[]
    for v in grafo:
        visitados[v]=False
